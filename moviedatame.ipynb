# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'E:\\Python-directory'

# %%
movie_df = pd.read_csv("MovieData.csv")

# %%
movie_df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
print("shape:",movie_df.shape)
# Out:
# shape: (5043, 28)

# %%
movie_df.keys()
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
print ("null values: \n") 
print (movie_df.isna())
# Out:
# null values:
#
#       color  director_name  num_critic_for_reviews  duration  \
# 0     False          False                   False     False
# 1     False          False                   False     False
# 2     False          False                   False     False
# 3     False          False                   False     False
# 4      True          False                    True      True
# 5     False          False                   False     False
# 6     False          False                   False     False
# 7     False          False                   False     False
# 8     False          False                   False     False
# 9     False          False                   False     False
# 10    False          False                   False     False
# 11    False          False                   False     False
# 12    False          False                   False     False
# 13    False          False                   False     False
# ...

# %%
print(movie_df.isna().sum())
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
print( "total null values: ")
movie_df.isna().sum().sum()
# Out:
# total null values:
# 2698

# %%
movie_df.describe()

#Avg movie duration is 107.2
#avg imdb is 6.64
#avg reviwes is 272
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
##747 out of 5043 movies are having more than 7.5 imdb rating.
#Genrally people watch this king of rating movies

movie_df[movie_df['imdb_score']>7.5].shape[0]
# Out:
# 747

# %%
movie1_df = movie_df.dropna(how='any')
print( "new dataframe shape: ", movie1_df.shape)
print( "old dataframe shape: ", movie_df.shape)
# Out:
# new dataframe shape:  (3756, 28)
# old dataframe shape:  (5043, 28)

# %%
movie_df.fillna(value=0, inplace = True) 
movie_df['language'].fillna("not given", inplace=True)
#movies_df['language'].fillna(method='ffill', inplace=True)     #fill the missing value could be ffill and bfill method
#movies_df['budget'].fillna(movies_df[budget].mean(), inplace=True)

# %%
drows_df = movie_df[movie_df.duplicated()]
print ("number of duplicate rows: ", drows_df.shape)

#specific column
drows_imdb_link= movie_df[movie_df.duplicated(['movie_imdb_link'])]
print (drows_imdb_link.shape)

#or
print (len(movie_df.movie_imdb_link.unique()))
# Out:
# number of duplicate rows:  (45, 28)
# (124, 28)
# 4919

# %%
#links were 124,  (4919 + 124 = 5043) total number of rows.
print ("shape of dataframe after dropping duplicates", movie1_df.drop_duplicates().shape )
# Out:
# shape of dataframe after dropping duplicates (3723, 28)

# %%
movie_groupby_ratings = movie_df.groupby(['imdb_score'])['movie_title'].count()
movie_groupby_ratings.plot()

#we can see more than 200  movies have rating of around 6.5

# %%
movie_groupby_duration = movie_df.groupby(['duration'])['movie_title'].count()
movie_groupby_duration.plot()

# %%
movie_df[movie_df['duration'] <= 100].shape[0]
# Out:
# 2194

# %%
movie_df[movie_df['duration'] >= 180].shape[0]

#See 68 movies have time duration more than equal to 3 hr.
#average movie time duration is 107 min
# Out:
# 68

# %%
#how many language's movies are in data
movie_df['language'].unique()
# Out:
# array(['English', 0, 'Japanese', 'French', 'Mandarin', 'Aboriginal',
#        'Spanish', 'Filipino', 'Hindi', 'Russian', 'Maya', 'Kazakh',
#        'Telugu', 'Cantonese', 'Icelandic', 'German', 'Aramaic', 'Italian',
#        'Dutch', 'Dari', 'Hebrew', 'Chinese', 'Mongolian', 'Swedish',
#        'Korean', 'Thai', 'Polish', 'Bosnian', 'None', 'Hungarian',
#        'Portuguese', 'Danish', 'Arabic', 'Norwegian', 'Czech', 'Kannada',
#        'Zulu', 'Panjabi', 'Tamil', 'Dzongkha', 'Vietnamese', 'Indonesian',
#        'Urdu', 'Romanian', 'Persian', 'Slovenian', 'Greek', 'Swahili'],
#       dtype=object)

# %%
movie_df[movie_df['language'] == 'English'].shape[0] # number of english movies
# Out:
# 4704

# %%
movie_df["profit"]=movie_df["gross"]-movie_df["budget"]
movie_df
# Out:
#                  color       director_name  num_critic_for_reviews  duration  \
# 0                Color       James Cameron                   723.0     178.0
# 1                Color      Gore Verbinski                   302.0     169.0
# 2                Color          Sam Mendes                   602.0     148.0
# 3                Color   Christopher Nolan                   813.0     164.0
# 4                    0         Doug Walker                     0.0       0.0
# 5                Color      Andrew Stanton                   462.0     132.0
# 6                Color           Sam Raimi                   392.0     156.0
# 7                Color        Nathan Greno                   324.0     100.0
# 8                Color         Joss Whedon                   635.0     141.0
# 9                Color         David Yates                   375.0     153.0
# 10               Color         Zack Snyder                   673.0     183.0
# ...

# %%
highest_imdb = movie_df.sort_values(by="imdb_score", ascending = False)

# %%
high = highest_imdb.loc[:,['movie_title', 'imdb_score','title_year', 'language', 'country', 'budget', 'director_name', 'duration', 'gross' ]]
high.head(20)
# Out:
#                                             movie_title  imdb_score  \
# 2765                      Towering Inferno                      9.5
# 1937                          The Shawshank Redemption          9.3
# 3466                                     The Godfather          9.2
# 4409                              Kickboxer: Vengeance          9.1
# 2824                               Dekalog                      9.1
# 3207                               Dekalog                      9.1
# 66                                     The Dark Knight          9.0
# 2837                            The Godfather: Part II          9.0
# 3481                                 Fargo                      9.0
# 339      The Lord of the Rings: The Return of the King          8.9
# 4822                                      12 Angry Men          8.9
# 4498                    The Good, the Bad and the Ugly          8.9
# 3355                                      Pulp Fiction          8.9
# ...

# %%
#indian top 5 rated movies
hindi = high[high['language']== 'Hindi']
hindi.head(10)
# Out:
#                               movie_title  imdb_score  title_year language  \
# 3870                             Airlift          8.5      2016.0    Hindi
# 3685                     Rang De Basanti          8.4      2006.0    Hindi
# 4160                Lage Raho Munna Bhai          8.2      2006.0    Hindi
# 3344                     My Name Is Khan          8.0      2010.0    Hindi
# 3510                          Veer-Zaara          7.9      2004.0    Hindi
# 4088                               Water          7.8      2005.0    Hindi
# 1056                               Earth          7.8      1998.0    Hindi
# 4385                        The Lunchbox          7.8      2013.0    Hindi
# 4528  Rocket Singh: Salesman of the Year          7.5      2009.0    Hindi
# 3789                   Gandhi, My Father          7.4      2007.0    Hindi
#
#      country       budget            director_name  duration      gross
# 3870   India    4400000.0               Raja Menon     130.0        0.0
# ...

# %%
#sns.scatterplot(x="imdb_score",y="profit",data=movie_df)
import matplotlib.pyplot as plt 
movie_df.groupby(['duration']).plot(x="imdb_score",y="profit", kind='bar') 
plt.show()
